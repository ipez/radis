# %%
from radis import getMolecule
CO = getMolecule("CO", 1, "B")
print(CO.Erovib(6, 1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from radis import getMolecule
#       2 CO = getMolecule("CO", 1, "B")
#       3 print(CO.Erovib(6, 1))
#
# File D:\0510\github\radis\radis\__init__.py:220
#     213 __all__ = [
#     214     "config",
#     215     "version",
#     216     "__version__",
#     217 ]
#     219 # prevent cyclic imports:
# --> 220 from . import api, db, io, lbl, los, misc, phys, spectrum, tools
#     221 from .api import *  # input / output common with ExoJax
#     222 from .db import *  # database of molecules
#
# File D:\0510\github\radis\radis\db\__init__.py:5
#       1 # -*- coding: utf-8 -*-
#       2 """Definition of molecules and list of spectroscopic constants
#       3 """
# ----> 5 from .molecules import Molecules, getMolecule
#       8 # %% Get list of supported molecules
# ...

# %%
import os
import radis
print(os.path.dirname(radis.__file__))
# Out:
# D:\0510\github\radis\radis
